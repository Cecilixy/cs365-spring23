# %%
import numpy as np
import matplotlib.pyplot as plt
import random
# include if using a Jupyter notebook
# %matplotlib inline

answer = 2022
total_count = 0
total_trial = 0
current_trial = 0
list_1 = []
list_2 = []
list_3 = []
list_4 = []
list_5 = []
list_6 = []
list_7 = []
list_8 = []
list_9 = []
list_10 = []

while (total_count < 100) :
    r = random.randrange(0, 9999, 1)
    total_trial +=1
    current_trial +=1
    if (r == 2022) :
        total_count +=1
        list_1.append(current_trial)
        current_trial = 0

total_trial = 0
        
while (total_count < 200) :
    r = random.randrange(0, 9999, 1)
    total_trial +=1
    current_trial +=1
    if (r == 2022) :
        total_count +=1
        list_2.append(current_trial)
        current_trial = 0
        
total_trial = 0       

while (total_count < 300) :
    r = random.randrange(0, 9999, 1)
    total_trial +=1
    current_trial +=1
    if (r == 2022) :
        total_count +=1
        list_3.append(current_trial)
        current_trial = 0

total_trial = 0

while (total_count < 400) :
    r = random.randrange(0, 9999, 1)
    total_trial +=1
    current_trial +=1
    if (r == 2022) :
        total_count +=1
        list_4.append(current_trial)
        current_trial = 0
        
total_trial = 0
        
while (total_count < 500) :
    r = random.randrange(0, 9999, 1)
    total_trial +=1
    current_trial +=1
    if (r == 2022) :
        total_count +=1
        list_5.append(current_trial)
        current_trial = 0
        
total_trial = 0

while (total_count < 600) :
    r = random.randrange(0, 9999, 1)
    total_trial +=1
    current_trial +=1
    if (r == 2022) :
        total_count +=1
        list_6.append(current_trial)
        current_trial = 0
        
total_trial = 0

while (total_count < 700) :
    r = random.randrange(0, 9999, 1)
    total_trial +=1
    current_trial +=1
    if (r == 2022) :
        total_count +=1
        list_7.append(current_trial)
        current_trial = 0
        
total_trial = 0

while (total_count < 800) :
    r = random.randrange(0, 9999, 1)
    total_trial +=1
    current_trial +=1
    if (r == 2022) :
        total_count +=1
        list_8.append(current_trial)
        current_trial = 0
        
total_trial = 0

while (total_count < 900) :
    r = random.randrange(0, 9999, 1)
    total_trial +=1
    current_trial +=1
    if (r == 2022) :
        total_count +=1
        list_9.append(current_trial)
        current_trial = 0
        
total_trial = 0

while (total_count < 1000) :
    r = random.randrange(0, 9999, 1)
    total_trial +=1
    current_trial +=1
    if (r == 2022) :
        total_count +=1
        list_10.append(current_trial)
        current_trial = 0
        
list_1_mean = np.mean(list_1)
list_2_mean = np.mean(list_2)
list_3_mean = np.mean(list_3)
list_4_mean = np.mean(list_4)
list_5_mean = np.mean(list_5)
list_6_mean = np.mean(list_6)
list_7_mean = np.mean(list_7)
list_8_mean = np.mean(list_8)
list_9_mean = np.mean(list_9)
list_10_mean = np.mean(list_10)

list_1_std = np.std(list_1)
list_2_std = np.std(list_2)
list_3_std = np.std(list_3)
list_4_std = np.std(list_4)
list_5_std = np.std(list_5)
list_6_std = np.std(list_6)
list_7_std = np.std(list_7)
list_8_std = np.std(list_8)
list_9_std = np.std(list_9)
list_10_std = np.std(list_10)

labels = ['100', '200', '300', '400', '500', '600', '700', '800', '900', '1000']
x_pos = np.arange(len(labels))
CTEs = [list_1_mean, list_2_mean, list_3_mean, list_4_mean, list_5_mean, list_6_mean, list_7_mean, list_8_mean, list_9_mean, list_10_mean]
error = [list_1_std, list_2_std, list_3_std, list_4_std, list_5_std, list_6_std, list_7_std, list_8_std, list_9_std, list_10_std]

fig, ax = plt.subplots()
ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,
       ecolor='black',
       capsize=10)
ax.set_ylabel('average number of trials')
ax.set_xticks(x_pos)
ax.set_xticklabels(labels)
ax.set_title('Strategy 1')
ax.yaxis.grid(True)

plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()

# %%
answer = 2022
total_count = 0
total_trial = 0
current_trial = 0
list_1 = []
list_2 = []
list_3 = []
list_4 = []
list_5 = []
list_6 = []
list_7 = []
list_8 = []
list_9 = []
list_10 = []

a = [x for x in range(10000)]

while (total_count < 100) :
    r = random.choice(a)
    total_trial +=1
    current_trial +=1
    a.remove(r)
    if (r == 2022) :
        total_count +=1
        list_1.append(current_trial)
        current_trial = 0
        a = [x for x in range(10000)]
        
a = [x for x in range(10000)]

while (total_count < 200) :
    r = random.choice(a)
    total_trial +=1
    current_trial +=1
    a.remove(r)
    if (r == 2022) :
        total_count +=1
        list_2.append(current_trial)
        current_trial = 0
        a = [x for x in range(10000)]
    
a = [x for x in range(10000)]

while (total_count < 300) :
    r = random.choice(a)
    total_trial +=1
    current_trial +=1
    a.remove(r)
    if (r == 2022) :
        total_count +=1
        list_3.append(current_trial)
        current_trial = 0
        a = [x for x in range(10000)]
    
a = [x for x in range(10000)]

while (total_count < 400) :
    r = random.choice(a)
    total_trial +=1
    current_trial +=1
    a.remove(r)
    if (r == 2022) :
        total_count +=1
        list_4.append(current_trial)
        current_trial = 0
        a = [x for x in range(10000)]
    
a = [x for x in range(10000)]

while (total_count < 500) :
    r = random.choice(a)
    total_trial +=1
    current_trial +=1
    a.remove(r)
    if (r == 2022) :
        total_count +=1
        list_5.append(current_trial)
        current_trial = 0
        a = [x for x in range(10000)]
    
a = [x for x in range(10000)]

while (total_count < 600) :
    r = random.choice(a)
    total_trial +=1
    current_trial +=1
    a.remove(r)
    if (r == 2022) :
        total_count +=1
        list_6.append(current_trial)
        current_trial = 0
        a = [x for x in range(10000)]
    
a = [x for x in range(10000)]

while (total_count < 700) :
    r = random.choice(a)
    total_trial +=1
    current_trial +=1
    a.remove(r)
    if (r == 2022) :
        total_count +=1
        list_7.append(current_trial)
        current_trial = 0
        a = [x for x in range(10000)]
    
a = [x for x in range(10000)]

while (total_count < 800) :
    r = random.choice(a)
    total_trial +=1
    current_trial +=1
    a.remove(r)
    if (r == 2022) :
        total_count +=1
        list_8.append(current_trial)
        current_trial = 0
        a = [x for x in range(10000)]
    
a = [x for x in range(10000)]

while (total_count < 900) :
    r = random.choice(a)
    total_trial +=1
    current_trial +=1
    a.remove(r)
    if (r == 2022) :
        total_count +=1
        list_9.append(current_trial)
        current_trial = 0
        a = [x for x in range(10000)]
    
a = [x for x in range(10000)]

while (total_count < 1000) :
    r = random.choice(a)
    total_trial +=1
    current_trial +=1
    a.remove(r)
    if (r == 2022) :
        total_count +=1
        list_10.append(current_trial)
        current_trial = 0
        a = [x for x in range(10000)]
    
list_1_mean = np.mean(list_1)
list_2_mean = np.mean(list_2)
list_3_mean = np.mean(list_3)
list_4_mean = np.mean(list_4)
list_5_mean = np.mean(list_5)
list_6_mean = np.mean(list_6)
list_7_mean = np.mean(list_7)
list_8_mean = np.mean(list_8)
list_9_mean = np.mean(list_9)
list_10_mean = np.mean(list_10)

list_1_std = np.std(list_1)
list_2_std = np.std(list_2)
list_3_std = np.std(list_3)
list_4_std = np.std(list_4)
list_5_std = np.std(list_5)
list_6_std = np.std(list_6)
list_7_std = np.std(list_7)
list_8_std = np.std(list_8)
list_9_std = np.std(list_9)
list_10_std = np.std(list_10)

labels = ['100', '200', '300', '400', '500', '600', '700', '800', '900', '1000']
x_pos = np.arange(len(labels))
CTEs = [list_1_mean, list_2_mean, list_3_mean, list_4_mean, list_5_mean, list_6_mean, list_7_mean, list_8_mean, list_9_mean, list_10_mean]
error = [list_1_std, list_2_std, list_3_std, list_4_std, list_5_std, list_6_std, list_7_std, list_8_std, list_9_std, list_10_std]

fig, ax = plt.subplots()
ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,
       ecolor='black',
       capsize=10)
ax.set_ylabel('average success')
ax.set_xticks(x_pos)
ax.set_xticklabels(labels)
ax.set_title('Problem 2 Strategy 2')
ax.yaxis.grid(True)

plt.tight_layout()
plt.savefig('Problem 2 Strategy 2.png')
plt.show()
